# %%
import os
import torch
from transformers import AutoTokenizer, AutoModel
import openai
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
# cur_os = sys.platform
# model_path = f"D:/github" if cur_os.startswith('win') else None

# %%
metadata = pd.read_csv('./tourInfo_copy.csv')
print(metadata.shape)
metadata.head()
# Out:
# (2004, 21)
#    Unnamed: 0                  addr1  addr2  areacode  booktour cat1   cat2
# 0           0      인천광역시 중구 연안부두로 61    NaN         2       NaN  A05  A0502  \
# 1           1     인천광역시 계양구 경명대로 977    NaN         2       NaN  A05  A0502
# 2           2    인천광역시 남동구 오봉동로4번길 9  (도림동)         2       NaN  A05  A0502
# 3           3  인천광역시 미추홀구 소성로326번길 4    NaN         2       NaN  A05  A0502
# 4           4      인천광역시 부평구 평천로 394    NaN         2       NaN  A05  A0502
#
#         cat3  contentid  contenttypeid  ...
# 0  A05020100     597467             39  ...  \
# 1  A05020100    2876098             39  ...
# 2  A05020100    2768130             39  ...
# 3  A05020100     135696             39  ...
# 4  A05020400     600680             39  ...
#
#                                           firstimage
# 0  http://tong.visitkorea.or.kr/cms/resource/74/1...  \
# 1  http://tong.visitkorea.or.kr/cms/resource/96/2...
# 2                                                NaN
# 3  http://tong.visitkorea.or.kr/cms/resource/54/1...
# 4  http://tong.visitkorea.or.kr/cms/resource/71/1...
#
#                                          firstimage2        mapx       mapy
# 0  http://tong.visitkorea.or.kr/cms/resource/74/1...  126.599864  37.453488  \
# 1  http://tong.visitkorea.or.kr/cms/resource/96/2...  126.715515  37.544160
# 2                                                NaN  126.729889  37.416801
# 3  http://tong.visitkorea.or.kr/cms/resource/54/1...  126.683246  37.437397
# 4  http://tong.visitkorea.or.kr/cms/resource/71/1...  126.734017  37.517217
#
#    mlevel  modifiedtime  sigungucode           tel     title zipcode
# 0     6.0  2.022120e+13           10  032-882-8505     가덕도횟집   22348
# 1     6.0  2.022100e+13            2           NaN  가든파티 계양점   21042
# 2     6.0  2.022120e+13            4           NaN    가리비칼국수   21656
# 3     6.0  2.022100e+13            3  032-426-7270    가마솥손두부   22238
# 4     6.0  2.022080e+13            6  032-512-8552        가보   21323
#
# [5 rows x 21 columns]

# %%
metadata = metadata[['addr1','addr2','firstimage','firstimage2', 'mapx', 'mapy', 'tel', 'title']]
metadata.head()
# Out:
#                    addr1  addr2
# 0      인천광역시 중구 연안부두로 61    NaN  \
# 1     인천광역시 계양구 경명대로 977    NaN
# 2    인천광역시 남동구 오봉동로4번길 9  (도림동)
# 3  인천광역시 미추홀구 소성로326번길 4    NaN
# 4      인천광역시 부평구 평천로 394    NaN
#
#                                           firstimage
# 0  http://tong.visitkorea.or.kr/cms/resource/74/1...  \
# 1  http://tong.visitkorea.or.kr/cms/resource/96/2...
# 2                                                NaN
# 3  http://tong.visitkorea.or.kr/cms/resource/54/1...
# 4  http://tong.visitkorea.or.kr/cms/resource/71/1...
#
#                                          firstimage2        mapx       mapy
# 0  http://tong.visitkorea.or.kr/cms/resource/74/1...  126.599864  37.453488  \
# 1  http://tong.visitkorea.or.kr/cms/resource/96/2...  126.715515  37.544160
# 2                                                NaN  126.729889  37.416801
# 3  http://tong.visitkorea.or.kr/cms/resource/54/1...  126.683246  37.437397
# 4  http://tong.visitkorea.or.kr/cms/resource/71/1...  126.734017  37.517217
#
#             tel     title
# 0  032-882-8505     가덕도횟집
# 1           NaN  가든파티 계양점
# 2           NaN    가리비칼국수
# 3  032-426-7270    가마솥손두부
# 4  032-512-8552        가보

# %%
tokenizer = AutoTokenizer.from_pretrained("beomi/KcELECTRA-base-v2022")
model = AutoModel.from_pretrained("beomi/KcELECTRA-base-v2022")
# Out:
# Some weights of the model checkpoint at beomi/KcELECTRA-base-v2022 were not used when initializing ElectraModel: ['discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
metadata['addr_em'] = metadata['addr1'].apply(lambda x: tokenizer.encode(x))
metadata.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 metadata['addr_em'] = metadata['addr1'].apply(lambda x: tokenizer.encode(x))
#       2 metadata.head()
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\pandas\core\series.py:4626, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4516 def apply(
#    4517     self,
#    4518     func: AggFuncType,
#    (...)
#    4521     **kwargs,
#    4522 ) -> DataFrame | Series:
#    4523     """
#    4524     Invoke function on values of Series.
#    4525
#    (...)
#    4624     dtype: float64
#    4625     """
# -> 4626     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[9], line 1, in <lambda>(x)
# ----> 1 metadata['addr_em'] = metadata['addr1'].apply(lambda x: tokenizer.encode(x))
#       2 metadata.head()
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\transformers\tokenization_utils_base.py:2319, in PreTrainedTokenizerBase.encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2282 @add_end_docstrings(
#    2283     ENCODE_KWARGS_DOCSTRING,
#    2284     """
#    (...)
#    2302     **kwargs,
#    2303 ) -> List[int]:
#    2304     """
#    2305     Converts a string to a sequence of ids (integer), using the tokenizer and vocabulary.
#    2306
#    (...)
#    2317             method).
#    2318     """
# -> 2319     encoded_inputs = self.encode_plus(
#    2320         text,
#    2321         text_pair=text_pair,
#    2322         add_special_tokens=add_special_tokens,
#    2323         padding=padding,
#    2324         truncation=truncation,
#    2325         max_length=max_length,
#    2326         stride=stride,
#    2327         return_tensors=return_tensors,
#    2328         **kwargs,
#    2329     )
#    2331     return encoded_inputs["input_ids"]
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\transformers\tokenization_utils_base.py:2727, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2717 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    2718 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    2719     padding=padding,
#    2720     truncation=truncation,
#    (...)
#    2724     **kwargs,
#    2725 )
# -> 2727 return self._encode_plus(
#    2728     text=text,
#    2729     text_pair=text_pair,
#    2730     add_special_tokens=add_special_tokens,
#    2731     padding_strategy=padding_strategy,
#    2732     truncation_strategy=truncation_strategy,
#    2733     max_length=max_length,
#    2734     stride=stride,
#    2735     is_split_into_words=is_split_into_words,
#    2736     pad_to_multiple_of=pad_to_multiple_of,
#    2737     return_tensors=return_tensors,
#    2738     return_token_type_ids=return_token_type_ids,
#    2739     return_attention_mask=return_attention_mask,
#    2740     return_overflowing_tokens=return_overflowing_tokens,
#    2741     return_special_tokens_mask=return_special_tokens_mask,
#    2742     return_offsets_mapping=return_offsets_mapping,
#    2743     return_length=return_length,
#    2744     verbose=verbose,
#    2745     **kwargs,
#    2746 )
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\transformers\tokenization_utils_fast.py:500, in PreTrainedTokenizerFast._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     478 def _encode_plus(
#     479     self,
#     480     text: Union[TextInput, PreTokenizedInput],
#    (...)
#     497     **kwargs,
#     498 ) -> BatchEncoding:
#     499     batched_input = [(text, text_pair)] if text_pair else [text]
# --> 500     batched_output = self._batch_encode_plus(
#     501         batched_input,
#     502         is_split_into_words=is_split_into_words,
#     503         add_special_tokens=add_special_tokens,
#     504         padding_strategy=padding_strategy,
#     505         truncation_strategy=truncation_strategy,
#     506         max_length=max_length,
#     507         stride=stride,
#     508         pad_to_multiple_of=pad_to_multiple_of,
#     509         return_tensors=return_tensors,
#     510         return_token_type_ids=return_token_type_ids,
#     511         return_attention_mask=return_attention_mask,
#     512         return_overflowing_tokens=return_overflowing_tokens,
#     513         return_special_tokens_mask=return_special_tokens_mask,
#     514         return_offsets_mapping=return_offsets_mapping,
#     515         return_length=return_length,
#     516         verbose=verbose,
#     517         **kwargs,
#     518     )
#     520     # Return tensor is None, then we can remove the leading batch axis
#     521     # Overflowing tokens are returned as a batch of output so we keep them in this case
#     522     if return_tensors is None and not return_overflowing_tokens:
#
# File ~\PycharmProjects\IncheonTourBot\venv\Lib\site-packages\transformers\tokenization_utils_fast.py:428, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose)
#     419 # Set the truncation and padding strategy and restore the initial configuration
#     420 self.set_truncation_and_padding(
#     421     padding_strategy=padding_strategy,
#     422     truncation_strategy=truncation_strategy,
#    (...)
#     425     pad_to_multiple_of=pad_to_multiple_of,
#     426 )
# --> 428 encodings = self._tokenizer.encode_batch(
#     429     batch_text_or_text_pairs,
#     430     add_special_tokens=add_special_tokens,
#     431     is_pretokenized=is_split_into_words,
#     432 )
#     434 # Convert encoding to dict
#     435 # `Tokens` has type: Tuple[
#     436 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     437 #                       List[EncodingFast]
#     438 #                    ]
#     439 # with nested dimensions corresponding to batch, overflows, sequence length
#     440 tokens_and_encodings = [
#     441     self._convert_encoding(
#     442         encoding=encoding,
#    (...)
#     451     for encoding in encodings
#     452 ]
#
# TypeError: TextEncodeInput must be Union[TextInputSequence, Tuple[InputSequence, InputSequence]]
